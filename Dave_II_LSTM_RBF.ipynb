# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install tensorflow==1.15
# !pip install keras==2.3.0
import keras
import keras.models as models
from keras.models import Sequential, Model
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.layers import BatchNormalization, Input, Add, Concatenate, concatenate
from keras.layers import TimeDistributed, LSTM
from keras.layers.convolutional import Conv2D
from keras.optimizers import SGD, Adam, RMSprop
from keras.models import model_from_json, load_model
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.callbacks import ModelCheckpoint
import cv2
import os
import csv
import numpy as np
import json
import matplotlib.pyplot as plt
from pathlib import Path
from keras.callbacks import CSVLogger
from keras.engine.topology import Layer
import keras.backend as K
import tensorflow as tf
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 41kB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.2)
# Collecting keras-applications>=1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 9.0MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.36.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.32.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.12.4)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 50.6MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.3.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.19.5)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 54.5MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15) (51.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.3.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.7.4.3)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=a4802af1e65fd56a0ea5b081f93fe708c2373261e79b7ead07ce82e1fcf416d2
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: keras-applications, tensorboard, tensorflow-estimator, gast, tensorflow
#   Found existing installation: tensorboard 2.4.0
#     Uninstalling tensorboard-2.4.0:
#       Successfully uninstalled tensorboard-2.4.0
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow 2.4.0
#     Uninstalling tensorflow-2.4.0:
#       Successfully uninstalled tensorflow-2.4.0
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1
# Collecting keras==2.3.0
#   Downloading https://files.pythonhosted.org/packages/1b/18/2e1ef121e5560ac24c7ac9e363aa5fa7006c40563c989e7211aba95b793a/Keras-2.3.0-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 7.4MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (3.13)
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.3.0
# Using TensorFlow backend.

# %%
steering = (10,20)
minS = 15
maxS = 15.7
n = 2

# %%
def load_images(path):
    # initialize loop variables
    numImages = 0
    inputs = []
    processDataPath = path + "ProcessData.csv"
    if not os.path.isfile(processDataPath):
        print('ProcessData.csv must be in folder %s' %path)
        return
    # read images in ProcessData.csv and append to input
    with open(processDataPath, 'rt') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            numImages = numImages+1
            if not os.path.isfile(path + (row[0].lower())):
                print('%s not found.' %(path+(row[0].lower())))
                return
            image=cv2.imread(path + (row[0].lower()))
            img = cv2.resize(image, (200, 66))
            img = img / 255.
            inputs.append(img)
    print("Total number of images: %d" %numImages)
    return inputs

# %%
def read_output_data(path):
    Y=[]
    # ensure path exists
    processDataPath = path+"ProcessData.csv"
    if not os.path.isfile(processDataPath):
        print('ProcessData.csv not found in %s.' %path)
        return
    # open ProcessData.csv and append steering values and speeds to Y and A
    with open(processDataPath, 'rt') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            s = (float(row[1]) - steering[0]) / (steering[1] - steering[0])
            Y.append([s])
    # return list of steering values and speeds
    return Y

# %%
def loadData(path):
    X = load_images(path)
    Y = read_output_data(path)
    X = np.array(X)
    Y = np.array(Y)
    return X, Y

# %%
def split_sequence(sequence, n_steps):
  x = list()
  for i in range(len(sequence)):
    end_ix = i + n_steps
    if end_ix > len(sequence) - 1:
      break
    seq_x = sequence[i:end_ix]
    x.append(seq_x)
  return np.array(x)

# %%
train_path = '/content/drive/My Drive/Colab Notebooks/DAVE-II-Hunter/DeepNNCar_Train2/'
X, Y = loadData(train_path)

print(X.shape)
print(Y.shape)
# Out:
# Total number of images: 1604
# (1604, 66, 200, 3)
# (1604, 1)

# %%
train_X = split_sequence(X, n)

# %%
outputs = []
for i in range(n, Y.shape[0]):
  l = [0] * 10
  if Y[i][0] < 0.1:
    l[0] = 1
  elif Y[i][0] < 0.2:
    l[1] = 1
  elif Y[i][0] < 0.3:
    l[2] = 1
  elif Y[i][0] < 0.4:
    l[3] = 1
  elif Y[i][0] < 0.5:
    l[4] = 1
  elif Y[i][0] < 0.6:
    l[5] = 1
  elif Y[i][0] < 0.7:
    l[6] = 1
  elif Y[i][0] < 0.8:
    l[7] = 1
  elif Y[i][0] < 0.9:
    l[8] = 1
  else:
    l[9] = 1
  outputs.append(l)
train_Y = np.array(outputs)
print(train_X.shape)
print(train_Y.shape)
# Out:
# (1602, 2, 66, 200, 3)
# (1602, 10)

# %%
class RBFLayer(Layer):
    def __init__(self, units, gamma, temp=None,**kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = K.cast_to_floatx(gamma)
        self.temp = temp
    def build(self, input_shape):
        self.mu = self.add_weight(name='mu',
                                  shape=(int(input_shape[1]), self.units),
                                  initializer=keras.initializers.RandomUniform(minval=-1, maxval=1, seed=1234),
                                  trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        diff = K.expand_dims(inputs) - self.mu
        if (self.temp):
            diff = diff / self.temp
        l2 = K.sum(K.pow(diff, 2), axis=1)
        res = K.exp(0.0)*l2
        return res

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)

    def get_config(self):
        # have to define get_config to be able to use model_from_json
        config = {
            'units': self.units,
            'gamma': self.gamma
        }
        base_config = super(RBFLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))


# this is a helper function
def softargmax(x,beta=1e10):
    """
    Perform argmax in a differential manner
    :param x: An array with the original inputs. `x` is expected to have spatial dimensions.
    :type x: `np.ndarray`
    :param beta: A large number to approximate argmax(`x`)
    :type y: float
    :return: argmax of tensor
    :rtype: `tensorflow.python.framework.ops.Tensor`
    """
    x = tf.convert_to_tensor(x)
    x_range = tf.range(10)
    x_range = tf.dtypes.cast(x_range,tf.float32)
    return tf.reduce_sum(tf.nn.softmax(x*beta) * x_range, axis=1)

RBF_LAMBDA = 0.5
def RBF_Soft_Loss(y_true,y_pred):
    lam = RBF_LAMBDA
    indices = softargmax(y_true)
    indices = tf.dtypes.cast(indices,tf.int32)
    y_pred = tf.dtypes.cast(y_pred,tf.float32)
    y_true = tf.dtypes.cast(y_true,tf.float32)
    row_ind = K.arange(K.shape(y_true)[0])
    full_indices = tf.stack([row_ind,indices],axis=1)
    d = tf.gather_nd(y_pred,full_indices)
    y_pred = K.log(1+ K.exp(lam - y_pred))
    S = K.sum(y_pred,axis=1) - K.log(1+K.exp(lam-d))
    y = K.sum(d + S)
    return y

def DistanceMetric(y_true,y_pred):
    e  = K.equal(K.argmax(y_true,axis=1),K.argmin(y_pred,axis=1))
    s = tf.reduce_sum(tf.cast(e, tf.float32))
    n = tf.cast(K.shape(y_true)[0],tf.float32)
    return s/n

# %%
class DaveIIModel():
    def __init__(self,anomalyDetector=False):
        self.input_size = (n, 66, 200, 3)
        self.num_classes = 10
        self.isAnomalyDetector = anomalyDetector
        model = Sequential()
        input1= Input(shape=(n, 66, 200, 3), name='images')
        steer_inp = TimeDistributed(BatchNormalization(epsilon=0.001, axis=-1,momentum=0.99))(input1)
        layer1 = TimeDistributed(Conv2D(24, (5, 5), padding="valid", strides=(2, 2), activation="relu"))(steer_inp)
        layer2 = TimeDistributed(Conv2D(36, (5, 5), padding="valid", strides=(2, 2), activation="relu"))(layer1)
        layer3 = TimeDistributed(Conv2D(48, (5, 5), padding="valid", strides=(2, 2), activation="relu"))(layer2)
        layer4 = TimeDistributed(Conv2D(64, (3, 3), padding="valid", strides=(1, 1), activation="relu"))(layer3)
        layer5 = TimeDistributed(Conv2D(64, (3, 3), padding="valid", strides=(1, 1)))(layer4) # add relu for old time sake
        layer6 = TimeDistributed(Flatten())(layer5)
        lstm_layer = LSTM(512)(layer6)
        layer8 = Dense(100, activation='relu')(lstm_layer)
        if(anomalyDetector):
            layer7 = Activation('tanh')(layer8)
            prediction = RBFLayer(self.num_classes,0.5)(layer7)
            model=Model(inputs=input1, outputs=prediction)
            model.summary()
            model.compile(loss=RBF_Soft_Loss,optimizer=keras.optimizers.Adam(),metrics=[DistanceMetric])
        else:
            layer6 = Activation('relu')(layer6) # remove me for old time sake
            layer7 = Dense(1164, activation='relu')(layer6)
            layer8 = Dense(100, activation='relu')(layer7)
            layer9 = Dense(50, activation='relu')(layer8)
            layer10 = Dense(10, activation='relu')(layer9)
            prediction = Dense(10, name='predictions',activation="softmax")(layer10)
            model=Model(inputs=input1, outputs=prediction)
            model.summary()
            model.compile(loss='categorical_crossentropy',optimizer=keras.optimizers.Adam(),metrics=['accuracy'])
        self.model = model

    def predict(self,X):
        predictions = self.model.predict(X)
        if (self.isAnomalyDetector):
            lam = RBF_LAMBDA
            Ok = np.exp(-1*predictions)
            top = Ok*(1+np.exp(lam)*Ok)
            bottom = np.prod(1+np.exp(lam)*Ok,axis=1)
            predictions = np.divide(top.T,bottom).T
        return predictions

    def getInputSize(self):
        return self.input_size

    def getNumberClasses(self):
        return self.num_classes

    def train(self,train_data_generator,validation_data_generator,saveTo,epochs=10,class_weight=None):

        if (self.isAnomalyDetector):
            checkpoint = ModelCheckpoint(saveTo, monitor='DistanceMetric', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
        else:
            checkpoint = ModelCheckpoint(saveTo, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
        self.model.fit_generator(
            train_data_generator,
            steps_per_epoch = math.ceil(train_data_generator.samples/train_data_generator.batch_size),
            epochs = epochs,
            validation_data = validation_data_generator,
            validation_steps = math.ceil(validation_data_generator.samples/validation_data_generator.batch_size),
            callbacks = [checkpoint],
            class_weight=class_weight)

    def train_data(self,X,Y,saveTo,epochs=10,class_weight=None):
        if (self.isAnomalyDetector):
            checkpoint = ModelCheckpoint(saveTo, monitor='DistanceMetric', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
        else:
            checkpoint = ModelCheckpoint(saveTo, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
        self.model.fit(X, Y,
                batch_size=8,
                epochs=epochs,
                verbose=1,
                callbacks=[checkpoint],
                shuffle=True)

    def load(self,weights):
        if (self.isAnomalyDetector):
            self.model = load_model(weights, custom_objects={'RBFLayer': RBFLayer,'DistanceMetric':DistanceMetric,'RBF_Soft_Loss':RBF_Soft_Loss})
        else:
            self.model = load_model(weights)

    def evaluate(self,X,Y):
        predictions = self.predict(X)
        accuracy = np.sum(np.argmax(predictions,axis=1) == np.argmax(Y, axis=1)) / len(Y)
        print('The accuracy of the model: ', accuracy)
        mse = mean_squared_error(np.argmax(Y, axis=1),np.argmax(predictions,axis=1))
        print('MSE of model: ', mse)
        print('Number of samples: ', len(Y))
    
    def evaluate_with_reject(self,X,Y):
        predictions = self.predict_with_reject(X)
        accuracy = np.sum(np.argmax(predictions,axis=1) == np.argmax(Y, axis=1)) / len(Y)
        print('The accuracy of the model: ', accuracy)
        mse = mean_squared_error(np.argmax(Y, axis=1),np.argmax(predictions,axis=1))
        print('MSE of model: ', mse)
        print('Number of samples: ', len(Y))
    
    def predict_with_reject(self,X):
        assert self.isAnomalyDetector, \
            print('Cannot reject a softmax classifier')
        predictions = self.model.predict(X)
        lam = RBF_LAMBDA
        Ok = np.exp(-1*predictions)
        bottom = np.prod(1+np.exp(lam)*Ok,axis=1)
        reject = 1.0/bottom
        top = Ok*(1+np.exp(lam)*Ok)
        predictions = np.divide(top.T,bottom).T
        predictions = np.concatenate((predictions,np.expand_dims(reject,axis=1)),axis=1)
        return predictions
    
    def reject(self,X):
        assert self.isAnomalyDetector, \
            print('Cannot reject a softmax classifier')
        predictions = self.model.predict(X)
        lam = RBF_LAMBDA
        Ok = np.exp(-1*predictions)
        bottom = np.prod(1+np.exp(lam)*Ok,axis=1)
        return 1.0/bottom

# %%
rbf_model = DaveIIModel(anomalyDetector=True)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# images (InputLayer)          (None, 2, 66, 200, 3)     0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 2, 66, 200, 3)     12
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 2, 31, 98, 24)     1824
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 2, 14, 47, 36)     21636
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 2, 5, 22, 48)      43248
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 2, 3, 20, 64)      27712
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 2, 1, 18, 64)      36928
# _________________________________________________________________
# time_distributed_21 (TimeDis (None, 2, 1152)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 512)               3409920
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_3 (Activation)    (None, 100)               0
# _________________________________________________________________
# rbf_layer_3 (RBFLayer)       (None, 10)                1000
# =================================================================
# Total params: 3,593,580
# Trainable params: 3,593,574
# Non-trainable params: 6
# _________________________________________________________________

# %%
MODEL_WEIGHT_LOC ='/content/drive/My Drive/Colab Notebooks/pretrained_weights/'
K.set_value(rbf_model.model.optimizer.lr,0.0001)
rbf_model.train_data(train_X, train_Y, saveTo=os.path.join(MODEL_WEIGHT_LOC,'DaveII_lstm_rbf_model.h5'),epochs=300)
# Out:
# Epoch 1/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 231.5021 - DistanceMetric: 0.4229
#
# Epoch 00001: DistanceMetric improved from -inf to 0.42289, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 2/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 206.6534 - DistanceMetric: 0.5367
#
# Epoch 00002: DistanceMetric improved from 0.42289 to 0.53669, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 3/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 191.1935 - DistanceMetric: 0.5734
#
# Epoch 00003: DistanceMetric improved from 0.53669 to 0.57338, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 4/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 178.1361 - DistanceMetric: 0.6026
#
# Epoch 00004: DistanceMetric improved from 0.57338 to 0.60261, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 5/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 166.1098 - DistanceMetric: 0.6225
#
# Epoch 00005: DistanceMetric improved from 0.60261 to 0.62251, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 6/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 154.4003 - DistanceMetric: 0.6530
#
# Epoch 00006: DistanceMetric improved from 0.62251 to 0.65299, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 7/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 143.3630 - DistanceMetric: 0.6884
#
# Epoch 00007: DistanceMetric improved from 0.65299 to 0.68843, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 8/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 134.5060 - DistanceMetric: 0.7170
#
# Epoch 00008: DistanceMetric improved from 0.68843 to 0.71704, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 9/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 125.7739 - DistanceMetric: 0.7139
#
# Epoch 00009: DistanceMetric did not improve from 0.71704
# Epoch 10/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 117.7094 - DistanceMetric: 0.7537
#
# Epoch 00010: DistanceMetric improved from 0.71704 to 0.75373, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 11/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 109.9301 - DistanceMetric: 0.7730
#
# Epoch 00011: DistanceMetric improved from 0.75373 to 0.77301, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 12/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 102.7400 - DistanceMetric: 0.7960
#
# Epoch 00012: DistanceMetric improved from 0.77301 to 0.79602, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 13/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 95.3834 - DistanceMetric: 0.8215
#
# Epoch 00013: DistanceMetric improved from 0.79602 to 0.82152, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 14/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 89.9588 - DistanceMetric: 0.8296
#
# Epoch 00014: DistanceMetric improved from 0.82152 to 0.82960, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 15/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 83.5341 - DistanceMetric: 0.8501
#
# Epoch 00015: DistanceMetric improved from 0.82960 to 0.85012, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 16/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 77.9321 - DistanceMetric: 0.8495
#
# Epoch 00016: DistanceMetric did not improve from 0.85012
# Epoch 17/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 72.5766 - DistanceMetric: 0.8762
#
# Epoch 00017: DistanceMetric improved from 0.85012 to 0.87624, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 18/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 68.1464 - DistanceMetric: 0.8881
#
# Epoch 00018: DistanceMetric improved from 0.87624 to 0.88806, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 19/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 63.4229 - DistanceMetric: 0.9036
#
# Epoch 00019: DistanceMetric improved from 0.88806 to 0.90361, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 20/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 59.1436 - DistanceMetric: 0.9241
#
# Epoch 00020: DistanceMetric improved from 0.90361 to 0.92413, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 21/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 55.6560 - DistanceMetric: 0.9185
#
# Epoch 00021: DistanceMetric did not improve from 0.92413
# Epoch 22/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 52.0538 - DistanceMetric: 0.9353
#
# Epoch 00022: DistanceMetric improved from 0.92413 to 0.93532, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 23/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 48.3293 - DistanceMetric: 0.9434
#
# Epoch 00023: DistanceMetric improved from 0.93532 to 0.94341, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 24/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 45.3869 - DistanceMetric: 0.9478
#
# Epoch 00024: DistanceMetric improved from 0.94341 to 0.94776, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 25/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 42.3844 - DistanceMetric: 0.9496
#
# Epoch 00025: DistanceMetric improved from 0.94776 to 0.94963, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 26/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 39.7488 - DistanceMetric: 0.9540
#
# Epoch 00026: DistanceMetric improved from 0.94963 to 0.95398, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 27/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 37.0619 - DistanceMetric: 0.9614
#
# Epoch 00027: DistanceMetric improved from 0.95398 to 0.96144, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 28/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 34.5440 - DistanceMetric: 0.9670
#
# Epoch 00028: DistanceMetric improved from 0.96144 to 0.96704, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 29/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 32.4653 - DistanceMetric: 0.9608
#
# Epoch 00029: DistanceMetric did not improve from 0.96704
# Epoch 30/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 30.2772 - DistanceMetric: 0.9639
#
# Epoch 00030: DistanceMetric did not improve from 0.96704
# Epoch 31/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 28.0999 - DistanceMetric: 0.9633
#
# Epoch 00031: DistanceMetric did not improve from 0.96704
# Epoch 32/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 26.0183 - DistanceMetric: 0.9695
#
# Epoch 00032: DistanceMetric improved from 0.96704 to 0.96953, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 33/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 24.2096 - DistanceMetric: 0.9764
#
# Epoch 00033: DistanceMetric improved from 0.96953 to 0.97637, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 34/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 22.2394 - DistanceMetric: 0.9757
#
# Epoch 00034: DistanceMetric did not improve from 0.97637
# Epoch 35/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 20.6502 - DistanceMetric: 0.9776
#
# Epoch 00035: DistanceMetric improved from 0.97637 to 0.97761, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 36/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 19.2415 - DistanceMetric: 0.9807
#
# Epoch 00036: DistanceMetric improved from 0.97761 to 0.98072, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 37/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 17.6866 - DistanceMetric: 0.9807
#
# Epoch 00037: DistanceMetric did not improve from 0.98072
# Epoch 38/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 16.3527 - DistanceMetric: 0.9826
#
# Epoch 00038: DistanceMetric improved from 0.98072 to 0.98259, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 39/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 15.1573 - DistanceMetric: 0.9845
#
# Epoch 00039: DistanceMetric improved from 0.98259 to 0.98445, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 40/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 13.8857 - DistanceMetric: 0.9838
#
# Epoch 00040: DistanceMetric did not improve from 0.98445
# Epoch 41/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 12.8430 - DistanceMetric: 0.9851
#
# Epoch 00041: DistanceMetric improved from 0.98445 to 0.98507, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 42/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 11.6994 - DistanceMetric: 0.9851
#
# Epoch 00042: DistanceMetric did not improve from 0.98507
# Epoch 43/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 10.8120 - DistanceMetric: 0.9869
#
# Epoch 00043: DistanceMetric improved from 0.98507 to 0.98694, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 44/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 10.0171 - DistanceMetric: 0.9857
#
# Epoch 00044: DistanceMetric did not improve from 0.98694
# Epoch 45/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 9.2153 - DistanceMetric: 0.9851
#
# Epoch 00045: DistanceMetric did not improve from 0.98694
# Epoch 46/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 8.5040 - DistanceMetric: 0.9863
#
# Epoch 00046: DistanceMetric did not improve from 0.98694
# Epoch 47/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 7.6247 - DistanceMetric: 0.9888
#
# Epoch 00047: DistanceMetric improved from 0.98694 to 0.98881, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 48/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 7.0869 - DistanceMetric: 0.9888
#
# Epoch 00048: DistanceMetric did not improve from 0.98881
# Epoch 49/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 6.4588 - DistanceMetric: 0.9894
#
# Epoch 00049: DistanceMetric improved from 0.98881 to 0.98943, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 50/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 5.9166 - DistanceMetric: 0.9900
#
# Epoch 00050: DistanceMetric improved from 0.98943 to 0.99005, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 51/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 5.4407 - DistanceMetric: 0.9900
#
# Epoch 00051: DistanceMetric did not improve from 0.99005
# Epoch 52/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 5.0206 - DistanceMetric: 0.9900
#
# Epoch 00052: DistanceMetric did not improve from 0.99005
# Epoch 53/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 4.7710 - DistanceMetric: 0.9894
#
# Epoch 00053: DistanceMetric did not improve from 0.99005
# Epoch 54/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 4.3005 - DistanceMetric: 0.9907
#
# Epoch 00054: DistanceMetric improved from 0.99005 to 0.99067, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 55/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 4.0123 - DistanceMetric: 0.9894
#
# Epoch 00055: DistanceMetric did not improve from 0.99067
# Epoch 56/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 3.8751 - DistanceMetric: 0.9882
#
# Epoch 00056: DistanceMetric did not improve from 0.99067
# Epoch 57/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 3.5342 - DistanceMetric: 0.9888
#
# Epoch 00057: DistanceMetric did not improve from 0.99067
# Epoch 58/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 3.3379 - DistanceMetric: 0.9882
#
# Epoch 00058: DistanceMetric did not improve from 0.99067
# Epoch 59/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.8850 - DistanceMetric: 0.9913
#
# Epoch 00059: DistanceMetric improved from 0.99067 to 0.99129, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 60/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.6786 - DistanceMetric: 0.9925
#
# Epoch 00060: DistanceMetric improved from 0.99129 to 0.99254, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 61/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.6642 - DistanceMetric: 0.9894
#
# Epoch 00061: DistanceMetric did not improve from 0.99254
# Epoch 62/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.4206 - DistanceMetric: 0.9913
#
# Epoch 00062: DistanceMetric did not improve from 0.99254
# Epoch 63/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.2063 - DistanceMetric: 0.9913
#
# Epoch 00063: DistanceMetric did not improve from 0.99254
# Epoch 64/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.1467 - DistanceMetric: 0.9925
#
# Epoch 00064: DistanceMetric did not improve from 0.99254
# Epoch 65/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.3037 - DistanceMetric: 0.9894
#
# Epoch 00065: DistanceMetric did not improve from 0.99254
# Epoch 66/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 2.1151 - DistanceMetric: 0.9932
#
# Epoch 00066: DistanceMetric improved from 0.99254 to 0.99316, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 67/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.7505 - DistanceMetric: 0.9944
#
# Epoch 00067: DistanceMetric improved from 0.99316 to 0.99440, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 68/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.6740 - DistanceMetric: 0.9925
#
# Epoch 00068: DistanceMetric did not improve from 0.99440
# Epoch 69/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.7700 - DistanceMetric: 0.9925
#
# Epoch 00069: DistanceMetric did not improve from 0.99440
# Epoch 70/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.6549 - DistanceMetric: 0.9919
#
# Epoch 00070: DistanceMetric did not improve from 0.99440
# Epoch 71/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.4879 - DistanceMetric: 0.9950
#
# Epoch 00071: DistanceMetric improved from 0.99440 to 0.99502, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 72/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.3671 - DistanceMetric: 0.9938
#
# Epoch 00072: DistanceMetric did not improve from 0.99502
# Epoch 73/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.2840 - DistanceMetric: 0.9950
#
# Epoch 00073: DistanceMetric did not improve from 0.99502
# Epoch 74/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.2335 - DistanceMetric: 0.9932
#
# Epoch 00074: DistanceMetric did not improve from 0.99502
# Epoch 75/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.1876 - DistanceMetric: 0.9950
#
# Epoch 00075: DistanceMetric did not improve from 0.99502
# Epoch 76/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.2394 - DistanceMetric: 0.9963
#
# Epoch 00076: DistanceMetric improved from 0.99502 to 0.99627, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 77/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.2504 - DistanceMetric: 0.9950
#
# Epoch 00077: DistanceMetric did not improve from 0.99627
# Epoch 78/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.1348 - DistanceMetric: 0.9956
#
# Epoch 00078: DistanceMetric did not improve from 0.99627
# Epoch 79/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.3247 - DistanceMetric: 0.9950
#
# Epoch 00079: DistanceMetric did not improve from 0.99627
# Epoch 80/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.6323 - DistanceMetric: 0.9932
#
# Epoch 00080: DistanceMetric did not improve from 0.99627
# Epoch 81/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.1226 - DistanceMetric: 0.9963
#
# Epoch 00081: DistanceMetric did not improve from 0.99627
# Epoch 82/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.0141 - DistanceMetric: 0.9956
#
# Epoch 00082: DistanceMetric did not improve from 0.99627
# Epoch 83/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.8925 - DistanceMetric: 0.9969
#
# Epoch 00083: DistanceMetric improved from 0.99627 to 0.99689, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 84/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.8767 - DistanceMetric: 0.9969
#
# Epoch 00084: DistanceMetric did not improve from 0.99689
# Epoch 85/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.2455 - DistanceMetric: 0.9944
#
# Epoch 00085: DistanceMetric did not improve from 0.99689
# Epoch 86/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.9195 - DistanceMetric: 0.9963
#
# Epoch 00086: DistanceMetric did not improve from 0.99689
# Epoch 87/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.8045 - DistanceMetric: 0.9981
#
# Epoch 00087: DistanceMetric improved from 0.99689 to 0.99813, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 88/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7423 - DistanceMetric: 0.9981
#
# Epoch 00088: DistanceMetric did not improve from 0.99813
# Epoch 89/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7467 - DistanceMetric: 0.9981
#
# Epoch 00089: DistanceMetric did not improve from 0.99813
# Epoch 90/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6924 - DistanceMetric: 0.9975
#
# Epoch 00090: DistanceMetric did not improve from 0.99813
# Epoch 91/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6779 - DistanceMetric: 0.9981
#
# Epoch 00091: DistanceMetric did not improve from 0.99813
# Epoch 92/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6953 - DistanceMetric: 0.9981
#
# Epoch 00092: DistanceMetric did not improve from 0.99813
# Epoch 93/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7328 - DistanceMetric: 0.9981
#
# Epoch 00093: DistanceMetric did not improve from 0.99813
# Epoch 94/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.5099 - DistanceMetric: 0.9925
#
# Epoch 00094: DistanceMetric did not improve from 0.99813
# Epoch 95/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.1087 - DistanceMetric: 0.9963
#
# Epoch 00095: DistanceMetric did not improve from 0.99813
# Epoch 96/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7187 - DistanceMetric: 0.9981
#
# Epoch 00096: DistanceMetric did not improve from 0.99813
# Epoch 97/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5993 - DistanceMetric: 0.9988
#
# Epoch 00097: DistanceMetric improved from 0.99813 to 0.99876, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 98/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6163 - DistanceMetric: 0.9969
#
# Epoch 00098: DistanceMetric did not improve from 0.99876
# Epoch 99/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5252 - DistanceMetric: 0.9988
#
# Epoch 00099: DistanceMetric did not improve from 0.99876
# Epoch 100/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5269 - DistanceMetric: 0.9981
#
# Epoch 00100: DistanceMetric did not improve from 0.99876
# Epoch 101/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5096 - DistanceMetric: 0.9981
#
# Epoch 00101: DistanceMetric did not improve from 0.99876
# Epoch 102/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5031 - DistanceMetric: 0.9981
#
# Epoch 00102: DistanceMetric did not improve from 0.99876
# Epoch 103/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4825 - DistanceMetric: 0.9994
#
# Epoch 00103: DistanceMetric improved from 0.99876 to 0.99938, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 104/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5117 - DistanceMetric: 0.9988
#
# Epoch 00104: DistanceMetric did not improve from 0.99938
# Epoch 105/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5011 - DistanceMetric: 0.9994
#
# Epoch 00105: DistanceMetric did not improve from 0.99938
# Epoch 106/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5363 - DistanceMetric: 0.9988
#
# Epoch 00106: DistanceMetric did not improve from 0.99938
# Epoch 107/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5846 - DistanceMetric: 0.9988
#
# Epoch 00107: DistanceMetric did not improve from 0.99938
# Epoch 108/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.3762 - DistanceMetric: 0.9944
#
# Epoch 00108: DistanceMetric did not improve from 0.99938
# Epoch 109/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.9827 - DistanceMetric: 0.9975
#
# Epoch 00109: DistanceMetric did not improve from 0.99938
# Epoch 110/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6390 - DistanceMetric: 0.9981
#
# Epoch 00110: DistanceMetric did not improve from 0.99938
# Epoch 111/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4715 - DistanceMetric: 1.0000
#
# Epoch 00111: DistanceMetric improved from 0.99938 to 1.00000, saving model to /content/drive/My Drive/Colab Notebooks/pretrained_weights/DaveII_lstm_rbf_model.h5
# Epoch 112/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4228 - DistanceMetric: 1.0000
#
# Epoch 00112: DistanceMetric did not improve from 1.00000
# Epoch 113/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4034 - DistanceMetric: 1.0000
#
# Epoch 00113: DistanceMetric did not improve from 1.00000
# Epoch 114/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3820 - DistanceMetric: 1.0000
#
# Epoch 00114: DistanceMetric did not improve from 1.00000
# Epoch 115/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3751 - DistanceMetric: 1.0000
#
# Epoch 00115: DistanceMetric did not improve from 1.00000
# Epoch 116/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3681 - DistanceMetric: 0.9994
#
# Epoch 00116: DistanceMetric did not improve from 1.00000
# Epoch 117/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3601 - DistanceMetric: 1.0000
#
# Epoch 00117: DistanceMetric did not improve from 1.00000
# Epoch 118/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3520 - DistanceMetric: 1.0000
#
# Epoch 00118: DistanceMetric did not improve from 1.00000
# Epoch 119/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3623 - DistanceMetric: 1.0000
#
# Epoch 00119: DistanceMetric did not improve from 1.00000
# Epoch 120/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4360 - DistanceMetric: 0.9988
#
# Epoch 00120: DistanceMetric did not improve from 1.00000
# Epoch 121/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3979 - DistanceMetric: 0.9994
#
# Epoch 00121: DistanceMetric did not improve from 1.00000
# Epoch 122/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5413 - DistanceMetric: 0.9988
#
# Epoch 00122: DistanceMetric did not improve from 1.00000
# Epoch 123/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.2782 - DistanceMetric: 0.9925
#
# Epoch 00123: DistanceMetric did not improve from 1.00000
# Epoch 124/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7350 - DistanceMetric: 0.9975
#
# Epoch 00124: DistanceMetric did not improve from 1.00000
# Epoch 125/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4396 - DistanceMetric: 1.0000
#
# Epoch 00125: DistanceMetric did not improve from 1.00000
# Epoch 126/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3776 - DistanceMetric: 1.0000
#
# Epoch 00126: DistanceMetric did not improve from 1.00000
# Epoch 127/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3268 - DistanceMetric: 1.0000
#
# Epoch 00127: DistanceMetric did not improve from 1.00000
# Epoch 128/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3008 - DistanceMetric: 1.0000
#
# Epoch 00128: DistanceMetric did not improve from 1.00000
# Epoch 129/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2897 - DistanceMetric: 1.0000
#
# Epoch 00129: DistanceMetric did not improve from 1.00000
# Epoch 130/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2811 - DistanceMetric: 1.0000
#
# Epoch 00130: DistanceMetric did not improve from 1.00000
# Epoch 131/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2761 - DistanceMetric: 1.0000
#
# Epoch 00131: DistanceMetric did not improve from 1.00000
# Epoch 132/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2686 - DistanceMetric: 1.0000
#
# Epoch 00132: DistanceMetric did not improve from 1.00000
# Epoch 133/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4829 - DistanceMetric: 0.9981
#
# Epoch 00133: DistanceMetric did not improve from 1.00000
# Epoch 134/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7264 - DistanceMetric: 0.9969
#
# Epoch 00134: DistanceMetric did not improve from 1.00000
# Epoch 135/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6127 - DistanceMetric: 0.9988
#
# Epoch 00135: DistanceMetric did not improve from 1.00000
# Epoch 136/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3642 - DistanceMetric: 1.0000
#
# Epoch 00136: DistanceMetric did not improve from 1.00000
# Epoch 137/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2826 - DistanceMetric: 1.0000
#
# Epoch 00137: DistanceMetric did not improve from 1.00000
# Epoch 138/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2557 - DistanceMetric: 1.0000
#
# Epoch 00138: DistanceMetric did not improve from 1.00000
# Epoch 139/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2436 - DistanceMetric: 1.0000
#
# Epoch 00139: DistanceMetric did not improve from 1.00000
# Epoch 140/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2387 - DistanceMetric: 1.0000
#
# Epoch 00140: DistanceMetric did not improve from 1.00000
# Epoch 141/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2338 - DistanceMetric: 1.0000
#
# Epoch 00141: DistanceMetric did not improve from 1.00000
# Epoch 142/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2295 - DistanceMetric: 1.0000
#
# Epoch 00142: DistanceMetric did not improve from 1.00000
# Epoch 143/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2300 - DistanceMetric: 1.0000
#
# Epoch 00143: DistanceMetric did not improve from 1.00000
# Epoch 144/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2305 - DistanceMetric: 1.0000
#
# Epoch 00144: DistanceMetric did not improve from 1.00000
# Epoch 145/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2392 - DistanceMetric: 1.0000
#
# Epoch 00145: DistanceMetric did not improve from 1.00000
# Epoch 146/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3958 - DistanceMetric: 0.9981
#
# Epoch 00146: DistanceMetric did not improve from 1.00000
# Epoch 147/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 1.2318 - DistanceMetric: 0.9900
#
# Epoch 00147: DistanceMetric did not improve from 1.00000
# Epoch 148/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6481 - DistanceMetric: 0.9981
#
# Epoch 00148: DistanceMetric did not improve from 1.00000
# Epoch 149/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3105 - DistanceMetric: 0.9994
#
# Epoch 00149: DistanceMetric did not improve from 1.00000
# Epoch 150/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2336 - DistanceMetric: 0.9994
#
# Epoch 00150: DistanceMetric did not improve from 1.00000
# Epoch 151/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2120 - DistanceMetric: 1.0000
#
# Epoch 00151: DistanceMetric did not improve from 1.00000
# Epoch 152/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1993 - DistanceMetric: 1.0000
#
# Epoch 00152: DistanceMetric did not improve from 1.00000
# Epoch 153/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1923 - DistanceMetric: 1.0000
#
# Epoch 00153: DistanceMetric did not improve from 1.00000
# Epoch 154/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1865 - DistanceMetric: 1.0000
#
# Epoch 00154: DistanceMetric did not improve from 1.00000
# Epoch 155/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1821 - DistanceMetric: 1.0000
#
# Epoch 00155: DistanceMetric did not improve from 1.00000
# Epoch 156/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1780 - DistanceMetric: 1.0000
#
# Epoch 00156: DistanceMetric did not improve from 1.00000
# Epoch 157/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1758 - DistanceMetric: 1.0000
#
# Epoch 00157: DistanceMetric did not improve from 1.00000
# Epoch 158/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1742 - DistanceMetric: 1.0000
#
# Epoch 00158: DistanceMetric did not improve from 1.00000
# Epoch 159/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1751 - DistanceMetric: 1.0000
#
# Epoch 00159: DistanceMetric did not improve from 1.00000
# Epoch 160/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1778 - DistanceMetric: 1.0000
#
# Epoch 00160: DistanceMetric did not improve from 1.00000
# Epoch 161/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2235 - DistanceMetric: 1.0000
#
# Epoch 00161: DistanceMetric did not improve from 1.00000
# Epoch 162/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6648 - DistanceMetric: 0.9975
#
# Epoch 00162: DistanceMetric did not improve from 1.00000
# Epoch 163/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4594 - DistanceMetric: 1.0000
#
# Epoch 00163: DistanceMetric did not improve from 1.00000
# Epoch 164/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4891 - DistanceMetric: 0.9969
#
# Epoch 00164: DistanceMetric did not improve from 1.00000
# Epoch 165/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3513 - DistanceMetric: 0.9988
#
# Epoch 00165: DistanceMetric did not improve from 1.00000
# Epoch 166/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2140 - DistanceMetric: 1.0000
#
# Epoch 00166: DistanceMetric did not improve from 1.00000
# Epoch 167/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1663 - DistanceMetric: 1.0000
#
# Epoch 00167: DistanceMetric did not improve from 1.00000
# Epoch 168/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1534 - DistanceMetric: 1.0000
#
# Epoch 00168: DistanceMetric did not improve from 1.00000
# Epoch 169/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1471 - DistanceMetric: 1.0000
#
# Epoch 00169: DistanceMetric did not improve from 1.00000
# Epoch 170/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1430 - DistanceMetric: 1.0000
#
# Epoch 00170: DistanceMetric did not improve from 1.00000
# Epoch 171/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1386 - DistanceMetric: 1.0000
#
# Epoch 00171: DistanceMetric did not improve from 1.00000
# Epoch 172/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1378 - DistanceMetric: 1.0000
#
# Epoch 00172: DistanceMetric did not improve from 1.00000
# Epoch 173/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1361 - DistanceMetric: 1.0000
#
# Epoch 00173: DistanceMetric did not improve from 1.00000
# Epoch 174/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1335 - DistanceMetric: 1.0000
#
# Epoch 00174: DistanceMetric did not improve from 1.00000
# Epoch 175/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1358 - DistanceMetric: 1.0000
#
# Epoch 00175: DistanceMetric did not improve from 1.00000
# Epoch 176/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1369 - DistanceMetric: 1.0000
#
# Epoch 00176: DistanceMetric did not improve from 1.00000
# Epoch 177/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1485 - DistanceMetric: 1.0000
#
# Epoch 00177: DistanceMetric did not improve from 1.00000
# Epoch 178/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1541 - DistanceMetric: 1.0000
#
# Epoch 00178: DistanceMetric did not improve from 1.00000
# Epoch 179/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1640 - DistanceMetric: 1.0000
#
# Epoch 00179: DistanceMetric did not improve from 1.00000
# Epoch 180/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1897 - DistanceMetric: 1.0000
#
# Epoch 00180: DistanceMetric did not improve from 1.00000
# Epoch 181/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6313 - DistanceMetric: 0.9969
#
# Epoch 00181: DistanceMetric did not improve from 1.00000
# Epoch 182/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3320 - DistanceMetric: 1.0000
#
# Epoch 00182: DistanceMetric did not improve from 1.00000
# Epoch 183/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2061 - DistanceMetric: 0.9994
#
# Epoch 00183: DistanceMetric did not improve from 1.00000
# Epoch 184/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2825 - DistanceMetric: 0.9994
#
# Epoch 00184: DistanceMetric did not improve from 1.00000
# Epoch 185/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3199 - DistanceMetric: 0.9981
#
# Epoch 00185: DistanceMetric did not improve from 1.00000
# Epoch 186/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3669 - DistanceMetric: 0.9975
#
# Epoch 00186: DistanceMetric did not improve from 1.00000
# Epoch 187/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1513 - DistanceMetric: 1.0000
#
# Epoch 00187: DistanceMetric did not improve from 1.00000
# Epoch 188/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1210 - DistanceMetric: 1.0000
#
# Epoch 00188: DistanceMetric did not improve from 1.00000
# Epoch 189/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1099 - DistanceMetric: 1.0000
#
# Epoch 00189: DistanceMetric did not improve from 1.00000
# Epoch 190/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1063 - DistanceMetric: 1.0000
#
# Epoch 00190: DistanceMetric did not improve from 1.00000
# Epoch 191/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1025 - DistanceMetric: 1.0000
#
# Epoch 00191: DistanceMetric did not improve from 1.00000
# Epoch 192/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1002 - DistanceMetric: 1.0000
#
# Epoch 00192: DistanceMetric did not improve from 1.00000
# Epoch 193/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0994 - DistanceMetric: 1.0000
#
# Epoch 00193: DistanceMetric did not improve from 1.00000
# Epoch 194/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1045 - DistanceMetric: 1.0000
#
# Epoch 00194: DistanceMetric did not improve from 1.00000
# Epoch 195/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2153 - DistanceMetric: 0.9994
#
# Epoch 00195: DistanceMetric did not improve from 1.00000
# Epoch 196/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1187 - DistanceMetric: 1.0000
#
# Epoch 00196: DistanceMetric did not improve from 1.00000
# Epoch 197/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1053 - DistanceMetric: 1.0000
#
# Epoch 00197: DistanceMetric did not improve from 1.00000
# Epoch 198/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1038 - DistanceMetric: 1.0000
#
# Epoch 00198: DistanceMetric did not improve from 1.00000
# Epoch 199/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1053 - DistanceMetric: 1.0000
#
# Epoch 00199: DistanceMetric did not improve from 1.00000
# Epoch 200/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2925 - DistanceMetric: 0.9981
#
# Epoch 00200: DistanceMetric did not improve from 1.00000
# Epoch 201/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.6400 - DistanceMetric: 0.9956
#
# Epoch 00201: DistanceMetric did not improve from 1.00000
# Epoch 202/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7106 - DistanceMetric: 0.9944
#
# Epoch 00202: DistanceMetric did not improve from 1.00000
# Epoch 203/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2077 - DistanceMetric: 1.0000
#
# Epoch 00203: DistanceMetric did not improve from 1.00000
# Epoch 204/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1262 - DistanceMetric: 1.0000
#
# Epoch 00204: DistanceMetric did not improve from 1.00000
# Epoch 205/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1057 - DistanceMetric: 1.0000
#
# Epoch 00205: DistanceMetric did not improve from 1.00000
# Epoch 206/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0956 - DistanceMetric: 1.0000
#
# Epoch 00206: DistanceMetric did not improve from 1.00000
# Epoch 207/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0896 - DistanceMetric: 1.0000
#
# Epoch 00207: DistanceMetric did not improve from 1.00000
# Epoch 208/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0851 - DistanceMetric: 1.0000
#
# Epoch 00208: DistanceMetric did not improve from 1.00000
# Epoch 209/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0829 - DistanceMetric: 1.0000
#
# Epoch 00209: DistanceMetric did not improve from 1.00000
# Epoch 210/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0799 - DistanceMetric: 1.0000
#
# Epoch 00210: DistanceMetric did not improve from 1.00000
# Epoch 211/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0785 - DistanceMetric: 1.0000
#
# Epoch 00211: DistanceMetric did not improve from 1.00000
# Epoch 212/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0768 - DistanceMetric: 1.0000
#
# Epoch 00212: DistanceMetric did not improve from 1.00000
# Epoch 213/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0762 - DistanceMetric: 1.0000
#
# Epoch 00213: DistanceMetric did not improve from 1.00000
# Epoch 214/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0749 - DistanceMetric: 1.0000
#
# Epoch 00214: DistanceMetric did not improve from 1.00000
# Epoch 215/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0738 - DistanceMetric: 1.0000
#
# Epoch 00215: DistanceMetric did not improve from 1.00000
# Epoch 216/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0742 - DistanceMetric: 1.0000
#
# Epoch 00216: DistanceMetric did not improve from 1.00000
# Epoch 217/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0780 - DistanceMetric: 1.0000
#
# Epoch 00217: DistanceMetric did not improve from 1.00000
# Epoch 218/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1651 - DistanceMetric: 0.9994
#
# Epoch 00218: DistanceMetric did not improve from 1.00000
# Epoch 219/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4663 - DistanceMetric: 0.9956
#
# Epoch 00219: DistanceMetric did not improve from 1.00000
# Epoch 220/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2518 - DistanceMetric: 0.9994
#
# Epoch 00220: DistanceMetric did not improve from 1.00000
# Epoch 221/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1528 - DistanceMetric: 0.9994
#
# Epoch 00221: DistanceMetric did not improve from 1.00000
# Epoch 222/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1670 - DistanceMetric: 0.9994
#
# Epoch 00222: DistanceMetric did not improve from 1.00000
# Epoch 223/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1166 - DistanceMetric: 1.0000
#
# Epoch 00223: DistanceMetric did not improve from 1.00000
# Epoch 224/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0799 - DistanceMetric: 1.0000
#
# Epoch 00224: DistanceMetric did not improve from 1.00000
# Epoch 225/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0706 - DistanceMetric: 1.0000
#
# Epoch 00225: DistanceMetric did not improve from 1.00000
# Epoch 226/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0672 - DistanceMetric: 1.0000
#
# Epoch 00226: DistanceMetric did not improve from 1.00000
# Epoch 227/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0644 - DistanceMetric: 1.0000
#
# Epoch 00227: DistanceMetric did not improve from 1.00000
# Epoch 228/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0630 - DistanceMetric: 1.0000
#
# Epoch 00228: DistanceMetric did not improve from 1.00000
# Epoch 229/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0624 - DistanceMetric: 1.0000
#
# Epoch 00229: DistanceMetric did not improve from 1.00000
# Epoch 230/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0615 - DistanceMetric: 1.0000
#
# Epoch 00230: DistanceMetric did not improve from 1.00000
# Epoch 231/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0626 - DistanceMetric: 1.0000
#
# Epoch 00231: DistanceMetric did not improve from 1.00000
# Epoch 232/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0663 - DistanceMetric: 1.0000
#
# Epoch 00232: DistanceMetric did not improve from 1.00000
# Epoch 233/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0692 - DistanceMetric: 1.0000
#
# Epoch 00233: DistanceMetric did not improve from 1.00000
# Epoch 234/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0731 - DistanceMetric: 1.0000
#
# Epoch 00234: DistanceMetric did not improve from 1.00000
# Epoch 235/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1533 - DistanceMetric: 0.9994
#
# Epoch 00235: DistanceMetric did not improve from 1.00000
# Epoch 236/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.7063 - DistanceMetric: 0.9932
#
# Epoch 00236: DistanceMetric did not improve from 1.00000
# Epoch 237/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3844 - DistanceMetric: 0.9981
#
# Epoch 00237: DistanceMetric did not improve from 1.00000
# Epoch 238/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1240 - DistanceMetric: 1.0000
#
# Epoch 00238: DistanceMetric did not improve from 1.00000
# Epoch 239/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0828 - DistanceMetric: 1.0000
#
# Epoch 00239: DistanceMetric did not improve from 1.00000
# Epoch 240/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0692 - DistanceMetric: 1.0000
#
# Epoch 00240: DistanceMetric did not improve from 1.00000
# Epoch 241/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0623 - DistanceMetric: 1.0000
#
# Epoch 00241: DistanceMetric did not improve from 1.00000
# Epoch 242/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0584 - DistanceMetric: 1.0000
#
# Epoch 00242: DistanceMetric did not improve from 1.00000
# Epoch 243/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0560 - DistanceMetric: 1.0000
#
# Epoch 00243: DistanceMetric did not improve from 1.00000
# Epoch 244/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0536 - DistanceMetric: 1.0000
#
# Epoch 00244: DistanceMetric did not improve from 1.00000
# Epoch 245/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0520 - DistanceMetric: 1.0000
#
# Epoch 00245: DistanceMetric did not improve from 1.00000
# Epoch 246/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0509 - DistanceMetric: 1.0000
#
# Epoch 00246: DistanceMetric did not improve from 1.00000
# Epoch 247/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0500 - DistanceMetric: 1.0000
#
# Epoch 00247: DistanceMetric did not improve from 1.00000
# Epoch 248/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0493 - DistanceMetric: 1.0000
#
# Epoch 00248: DistanceMetric did not improve from 1.00000
# Epoch 249/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0498 - DistanceMetric: 1.0000
#
# Epoch 00249: DistanceMetric did not improve from 1.00000
# Epoch 250/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0498 - DistanceMetric: 1.0000
#
# Epoch 00250: DistanceMetric did not improve from 1.00000
# Epoch 251/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0499 - DistanceMetric: 1.0000
#
# Epoch 00251: DistanceMetric did not improve from 1.00000
# Epoch 252/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0509 - DistanceMetric: 1.0000
#
# Epoch 00252: DistanceMetric did not improve from 1.00000
# Epoch 253/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0543 - DistanceMetric: 1.0000
#
# Epoch 00253: DistanceMetric did not improve from 1.00000
# Epoch 254/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2049 - DistanceMetric: 0.9988
#
# Epoch 00254: DistanceMetric did not improve from 1.00000
# Epoch 255/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1923 - DistanceMetric: 0.9988
#
# Epoch 00255: DistanceMetric did not improve from 1.00000
# Epoch 256/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.5716 - DistanceMetric: 0.9963
#
# Epoch 00256: DistanceMetric did not improve from 1.00000
# Epoch 257/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.2298 - DistanceMetric: 0.9994
#
# Epoch 00257: DistanceMetric did not improve from 1.00000
# Epoch 258/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1037 - DistanceMetric: 1.0000
#
# Epoch 00258: DistanceMetric did not improve from 1.00000
# Epoch 259/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0650 - DistanceMetric: 1.0000
#
# Epoch 00259: DistanceMetric did not improve from 1.00000
# Epoch 260/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0533 - DistanceMetric: 1.0000
#
# Epoch 00260: DistanceMetric did not improve from 1.00000
# Epoch 261/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0491 - DistanceMetric: 1.0000
#
# Epoch 00261: DistanceMetric did not improve from 1.00000
# Epoch 262/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0461 - DistanceMetric: 1.0000
#
# Epoch 00262: DistanceMetric did not improve from 1.00000
# Epoch 263/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0445 - DistanceMetric: 1.0000
#
# Epoch 00263: DistanceMetric did not improve from 1.00000
# Epoch 264/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0431 - DistanceMetric: 1.0000
#
# Epoch 00264: DistanceMetric did not improve from 1.00000
# Epoch 265/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0418 - DistanceMetric: 1.0000
#
# Epoch 00265: DistanceMetric did not improve from 1.00000
# Epoch 266/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0413 - DistanceMetric: 1.0000
#
# Epoch 00266: DistanceMetric did not improve from 1.00000
# Epoch 267/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0410 - DistanceMetric: 1.0000
#
# Epoch 00267: DistanceMetric did not improve from 1.00000
# Epoch 268/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0406 - DistanceMetric: 1.0000
#
# Epoch 00268: DistanceMetric did not improve from 1.00000
# Epoch 269/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0421 - DistanceMetric: 1.0000
#
# Epoch 00269: DistanceMetric did not improve from 1.00000
# Epoch 270/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0440 - DistanceMetric: 1.0000
#
# Epoch 00270: DistanceMetric did not improve from 1.00000
# Epoch 271/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0469 - DistanceMetric: 1.0000
#
# Epoch 00271: DistanceMetric did not improve from 1.00000
# Epoch 272/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0470 - DistanceMetric: 1.0000
#
# Epoch 00272: DistanceMetric did not improve from 1.00000
# Epoch 273/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0484 - DistanceMetric: 1.0000
#
# Epoch 00273: DistanceMetric did not improve from 1.00000
# Epoch 274/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0511 - DistanceMetric: 1.0000
#
# Epoch 00274: DistanceMetric did not improve from 1.00000
# Epoch 275/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0560 - DistanceMetric: 1.0000
#
# Epoch 00275: DistanceMetric did not improve from 1.00000
# Epoch 276/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0585 - DistanceMetric: 1.0000
#
# Epoch 00276: DistanceMetric did not improve from 1.00000
# Epoch 277/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0597 - DistanceMetric: 1.0000
#
# Epoch 00277: DistanceMetric did not improve from 1.00000
# Epoch 278/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3215 - DistanceMetric: 0.9994
#
# Epoch 00278: DistanceMetric did not improve from 1.00000
# Epoch 279/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.4692 - DistanceMetric: 0.9975
#
# Epoch 00279: DistanceMetric did not improve from 1.00000
# Epoch 280/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.3822 - DistanceMetric: 0.9963
#
# Epoch 00280: DistanceMetric did not improve from 1.00000
# Epoch 281/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.1434 - DistanceMetric: 0.9994
#
# Epoch 00281: DistanceMetric did not improve from 1.00000
# Epoch 282/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0605 - DistanceMetric: 1.0000
#
# Epoch 00282: DistanceMetric did not improve from 1.00000
# Epoch 283/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0473 - DistanceMetric: 1.0000
#
# Epoch 00283: DistanceMetric did not improve from 1.00000
# Epoch 284/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0419 - DistanceMetric: 1.0000
#
# Epoch 00284: DistanceMetric did not improve from 1.00000
# Epoch 285/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0392 - DistanceMetric: 1.0000
#
# Epoch 00285: DistanceMetric did not improve from 1.00000
# Epoch 286/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0368 - DistanceMetric: 1.0000
#
# Epoch 00286: DistanceMetric did not improve from 1.00000
# Epoch 287/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0351 - DistanceMetric: 1.0000
#
# Epoch 00287: DistanceMetric did not improve from 1.00000
# Epoch 288/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0340 - DistanceMetric: 1.0000
#
# Epoch 00288: DistanceMetric did not improve from 1.00000
# Epoch 289/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0327 - DistanceMetric: 1.0000
#
# Epoch 00289: DistanceMetric did not improve from 1.00000
# Epoch 290/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0321 - DistanceMetric: 1.0000
#
# Epoch 00290: DistanceMetric did not improve from 1.00000
# Epoch 291/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0316 - DistanceMetric: 1.0000
#
# Epoch 00291: DistanceMetric did not improve from 1.00000
# Epoch 292/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0317 - DistanceMetric: 1.0000
#
# Epoch 00292: DistanceMetric did not improve from 1.00000
# Epoch 293/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0310 - DistanceMetric: 1.0000
#
# Epoch 00293: DistanceMetric did not improve from 1.00000
# Epoch 294/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0308 - DistanceMetric: 1.0000
#
# Epoch 00294: DistanceMetric did not improve from 1.00000
# Epoch 295/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0310 - DistanceMetric: 1.0000
#
# Epoch 00295: DistanceMetric did not improve from 1.00000
# Epoch 296/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0316 - DistanceMetric: 1.0000
#
# Epoch 00296: DistanceMetric did not improve from 1.00000
# Epoch 297/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0326 - DistanceMetric: 1.0000
#
# Epoch 00297: DistanceMetric did not improve from 1.00000
# Epoch 298/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0350 - DistanceMetric: 1.0000
#
# Epoch 00298: DistanceMetric did not improve from 1.00000
# Epoch 299/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0369 - DistanceMetric: 1.0000
#
# Epoch 00299: DistanceMetric did not improve from 1.00000
# Epoch 300/300
# 1602/1602 [==============================] - 3s 2ms/step - loss: 0.0438 - DistanceMetric: 1.0000
#
# Epoch 00300: DistanceMetric did not improve from 1.00000

# %%
test_path = '/content/drive/My Drive/Colab Notebooks/DAVE-II-Hunter/DeepNNCar_Train1/'
X_test, Y_test = loadData(test_path)

print(X_test.shape)
print(Y_test.shape)

test_X = split_sequence(X_test, n)
# Out:
# Total number of images: 1076
# (1076, 66, 200, 3)
# (1076, 1)

# %%
old_results = rbf_model.reject(test_X)
print(old_results.mean())
# Out:
# 0.59079355

# %%
from google.colab.patches import cv2_imshow
from skimage.util import random_noise
def load_images_2(path):
    # initialize loop variables
    numImages = 0
    new_images = []
    alpha = 1
    beta = 200
    processDataPath = path + "ProcessData.csv"
    if not os.path.isfile(processDataPath):
        print('ProcessData.csv must be in folder %s' %path)
        return
    # read images in ProcessData.csv and append to input
    with open(processDataPath, 'rt') as csvfile:
        reader = csv.reader(csvfile)
        for i, row in enumerate(reader):
            numImages = numImages+1
            if not os.path.isfile(path + (row[0].lower())):
                print('%s not found.' %(path+(row[0].lower())))
                return
            img = cv2.imread(path + (row[0].lower()))
            img = cv2.resize(img, (200, 66))
            if 500 <= i < 1000:
                # new_image = np.zeros(img.shape, np.uint8)
                # for y in range(img.shape[0]):
                #     for x in range(img.shape[1]):
                #         for c in range(img.shape[2]):
                #             new_image[y,x,c] = np.clip(alpha*img[y,x,c] + beta, 0, 255)
                # new_image = new_image / 255.
                gimg = random_noise(img, mode='pepper', amount=0.5)
                # gimg = random_noise(img, mode='speckle', var=0.3)
                noise_img = np.array(255*gimg, dtype = 'uint8')
                new_image = noise_img / 255.
                new_images.append(new_image)
            else:
                img = img / 255.
                new_images.append(img)
    print("Total number of images: %d" %numImages)
    return np.array(new_images)
new = load_images_2('/content/drive/My Drive/Colab Notebooks/DAVE-II-Hunter/DeepNNCar_Train1/')
# Out:
# Total number of images: 1076

# %%
test_X_new = split_sequence(new, n)
new_results = rbf_model.reject(test_X_new)
print(new_results.mean())
# Out:
# 0.6338685

# %%
plt.plot(old_results)
plt.plot(new_results)
plt.legend(['old', 'new'])
# plt.title('Dave-II-LSTM-RBF 200 Brighter')
plt.title('Dave-II-LSTM-RBF Speckle')
plt.show()

# %%
from skimage.util import random_noise
img = cv2.imread('/content/drive/My Drive/Colab Notebooks/DAVE-II-Hunter/DeepNNCar_Train1/frame600.jpg')
cv2_imshow(img)
img = cv2.resize(img, (200, 66))
# img = img / 255.
gimg = random_noise(img, mode='speckle', var=0.3)
noise_img = np.array(255*gimg, dtype = 'uint8')
cv2_imshow(noise_img)
# Out:
# <PIL.Image.Image image mode=RGB size=320x240 at 0x7F6A90181518>
# <PIL.Image.Image image mode=RGB size=200x66 at 0x7F6A90181518>
